# %%
import re

# %% [markdown]
# Регулярные выражения (Regular Expressions, regex) – это простой язык «поисковых запросов» для поиска шаблонов в тексте.

# %% [markdown]
# **Ссылки для входа:**
#
# *[medium на русском](https://medium.com/nuances-of-programming/%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE-%D0%BF%D0%BE-%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E-%D0%BC%D0%BE%D0%B4%D1%83%D0%BB%D1%8F-%D1%80%D0%B5%D0%B3%D1%83%D0%BB%D1%8F%D1%80%D0%BD%D1%8B%D1%85-%D0%B2%D1%8B%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B9-python-774fb2b62218)
#
# *[habr](https://habr.com/ru/post/349860/)
#
# КАРТИНКА ИЗ ХАБР:

# %%
from IPython.display import Image
Image(filename='xtafnjpq-xw3lu0aisu68q22elg.png')

# %% [markdown]
# *[много текста на русском](http://blog.dzinko.org/2011/03/python.html)
#
# *[множество примеров](http://ilnurgi1.ru/docs/python/modules/re.html)
#
# **Если все прочитать — все будет понятно!**

# %%
text = 'Что такое регулярные выражения и как их использовать?\
        Говоря простым языком, регулярное выражение — это последовательность символов,\
        используемая для поиска и замены текста в строке или файле. Как уже было упомянуто,\
        их поддерживает множество языков общего назначения: Python, Perl, R.\
        Так что изучение регулярных выражений рано или поздно пригодится.'

# %%
pattern = 'регулярн[а-я]+ выражен[а-я]+'

# %%
# match
result = re.match('Что', text)
print(type(result))
print(result)
print('Нашел' if result else 'Не нашел')
# Out:
# <class 're.Match'>
# <re.Match object; span=(0, 3), match='Что'>
# Нашел

# %%
from IPython.display import Image
Image(filename='re-func.png')

# %%
result.group(0)
# Out:
# 'Что'

# %%
print(result.start(), result.end())
type(result.start())
# Out:
# 0 3
# int

# %%
# search
re.search(pattern, text)
# Out:
# <re.Match object; span=(10, 30), match='регулярные выражения'>

# %%
# findall
re.findall(pattern, text)
# Out:
# ['регулярные выражения', 'регулярное выражение', 'регулярных выражений']

# %%
# ОСНОВНЫЕ ОПЕРАТОРЫ:
Image(filename='operators.png')

# %%
# 'жадный поиск'
# найти все символьные элементы подряд, до пробела
greedy_search = re.findall('[\w]+', text)
greedy_search[:8]
# Out:
# ['Что', 'такое', 'регулярные', 'выражения', 'и', 'как', 'их', 'использовать']

# %%
second_search = re.findall('[\w]*', text)
second_search[:8]
# Out:
# ['Что', '', 'такое', '', 'регулярные', '', 'выражения', '']

# %%
import re
text = '8888888888888safd89493ff83'

# %%
third_search = re.findall('[\d]', text)
third_search
# Out:
# ['8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '9',
#  '4',
#  '9',
#  '3',
#  '8',
#  '3']

# %%
third_search = re.findall('[\w]?', text)
third_search[:8]
# Out:
# ['Ч', 'т', 'о', '', 'т', 'а', 'к', 'о']

# %%
# разобъем текст на предложение (примитивным вариантом)
res = re.split('[\.?]', text)

# %%
len(res)
# Out:
# 5

# %%
# произведем замену
res = re.sub(pattern, 'Regex', text)
res
# Out:
# 'Что такое Regex и как их использовать?        Говоря простым языком, Regex — это последовательность символов,        используемая для поиска и замены текста в строке или файле. Как уже было упомянуто,        их поддерживает множество языков общего назначения: Python, Perl, R.        Так что изучение Regex рано или поздно пригодится.'

# %%
# ИЛИ
fastest_animal = 'Гепард - самое быстрое животное'
re.findall('гепард|Гепард', fastest_animal)
# Out:
# ['Гепард']

# %%
# группировка
numbers = '55 3333 55 444 33 5555'
re.findall('\d+', numbers)
# Out:
# ['55', '3333', '55', '444', '33', '5555']

# %%
re.findall('(\d)+', numbers)
# Out:
# ['5', '3', '5', '4', '3', '5']

# %%
re.findall('((\d)+\s)', numbers)
# Out:
# [('55 ', '5'), ('3333 ', '3'), ('55 ', '5'), ('444 ', '4'), ('33 ', '3')]

# %%
# Lookaround
Image(filename='pos-check.png')

# %%
# Lookaround
prices = 'RUB4.44, RUB10.88'
regex_prices = '(?<=RUB)[0-9\.]*'

re.findall(regex_prices, prices)
# Out:
# ['4.44', '10.88']

# %%
# обращение к группам
# 'r' - row string - чистая строка
date = '08/30/1991'
re.sub(r'(\d\d)/(\d\d)/(\d{4})', r'\2.\1.\3', date)
# Out:
# '30.08.1991'

# %% [markdown]
# При наличии подгрупп в шаблоне можно ссылаться на них через соответствующий порядковый номер при помощи \1, \2, \3, ...

# %% [markdown]
# [про \1](http://qaru.site/questions/492075/python-regular-expression-1)

# %% [markdown]
# ### Практика

# %% [markdown]
# [тестер регулярных выражений](https://regex101.com/)

# %%
import re

# %%
# ОСНОВНЫЕ ОПЕРАТОРЫ:
Image(filename='operators.png')

# %%
# необходимо проверить пароль на соответствие тому, что в нем 8 символов, после которых 4 цифры
password = 'password1234'

# %%
pwd_pattern = r'\w{8}\d{4}'
result = re.match(pwd_pattern, password)
result
# Out:
# <re.Match object; span=(0, 12), match='password1234'>

# %%
# необходимо из строки с условными датами вытащить их
registration = 'Date of start: 4-12. Date of registration: 20-11'

# %%
re.findall(r'\: (\d{,2}-\d{,2})', registration)
# Out:
# ['4-12', '20-11']

# %%
# простыс способом определить домен в зоне .com
domain = 'www.site.com'

# %%
re.findall('www.+.com', domain)

# %%
# напишите регулярку, которая отберет только валидный email в зоне com
emails = ['n.john.smith@gmail.com', '87victory@hotmail.com', '!#mary-=@msca.net']

# %%
regex_mails =

# %%
for email in emails:
    if re.match(regex_mails, email):
        print('The email {} is a valid email'.format(email))
    else:
        print('The email {} is invalid'.format(email))

# %%
# напишите регулярку, которая отберет только валидный пароль по критериям:
# - содержит латинские символы в верхнем и нижнем регистре;
# - содержит числа;
# - содержит символы из *, #, $, %, !, &, .;
# - от 8 до 20 символов в длину;
passwords = ['Apple34!rose', 'My87hou#4$', 'abc123']

# %%
regex_pass =

# %%
for password in passwords:
    if re.search(regex_pass, password):
        print('The password {} is a valid password'.format(password))
    else:
        print('The password {} is invalid'.format(password))

# %%
# выделить группы символов из посадочного талона, где:
# - первые 2 символа - это авиакомпания;
# - 4 следующие символа - номер рейса;
# - 3 следующих символа - аэропорт отправления;
# - 3 следюущих - аэропорт прибытия;
# - оставшиеся - дата рейса
# Все буквы всегда в верхнем регистре

# %%
flight = 'Boarding pass: LA4214 AER-CDB 06NOV'

# %%
regex_flight = r'([A-Z]{2})(\d{4})\s([A-Z]{3})\-([A-Z]{3})\s(\d{2}[A-Z]{3})'

# %%
flight_result = re.findall(regex_flight, flight)
# flight_result = list(flight_result[0])

# %%
print(flight_result)
print(type(flight_result[0]))
# Out:
# [('LA', '4214', 'AER', 'CDB', '06NOV')]
# <class 'tuple'>

# %%
# напишите регулярку, которая отберет только животных с их количество
my_pets = 'У меня 2 кошки, 1 собака и 3 попугая'

# %%
regex_pets = r'\d+\s\w+'

# %%
result_pets = re.findall(regex_pets, my_pets)

# %%
result_pets
# Out:
# ['2 кошки', '1 собака', '3 попугая']

# %% [markdown]
# **Задание:**

# %% [markdown]
# Напишите функцию, которая будет удалять все последовательные повторы слов из заданной строки.

# %% [markdown]
# **[Решение и логика](https://ru.stackoverflow.com/questions/1045815/%d0%9a%d0%b0%d0%ba-%d1%83%d0%b4%d0%b0%d0%bb%d0%b8%d1%82%d1%8c-%d0%bf%d0%be%d1%81%d0%bb%d0%b5%d0%b4%d0%be%d0%b2%d0%b0%d1%82%d0%b5%d0%bb%d1%8c%d0%bd%d1%8b%d0%b5-%d0%bf%d0%be%d0%b2%d1%82%d0%be%d1%80%d1%8b-%d1%81%d0%bb%d0%be%d0%b2%d0%b0-%d0%b2-%d1%81%d1%82%d1%80%d0%be%d0%ba%d0%b5-%d1%81-%d0%bf%d0%be%d0%bc%d0%be%d1%89%d1%8c%d1%8e-%d1%80%d0%b5%d0%b3%d1%83%d0%bb%d1%8f%d1%80%d0%bd%d1%8b%d1%85-%d0%b2%d1%8b%d1%80%d0%b0%d0%b6%d0%b5%d0%bd?noredirect=1#comment1785296_1045815)**
